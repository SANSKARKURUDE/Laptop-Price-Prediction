# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptopData.csv')

df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.drop(columns = 'Unnamed: 0',inplace = True)
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.describe()
# Out:
#                Price
# count    1273.000000
# mean    59955.814073
# std     37332.251005
# min      9270.720000
# 25%     31914.720000
# 50%     52161.120000
# 75%     79333.387200
# max    324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 112.1+ KB

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', nan, 'Chuwi',
#        'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df.dropna(inplace = True)

print(df.info())
df['Company'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.3+ KB
# None
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
index1 = df[df.Inches == '?'].index

df.drop(index1,inplace = True)
print(df['Inches'].unique())
df.info()
# Out:
# ['13.3' '15.6' '15.4' '14' '12' '17.3' '13.5' '12.5' '13' '18.4' '13.9'
#  '11.6' '25.6' '35.6' '12.3' '27.3' '24' '33.5' '31.6' '17' '15' '14.1'
#  '11.3' '10.1']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1272 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1272 non-null   object
#  1   TypeName          1272 non-null   object
#  2   Inches            1272 non-null   object
#  3   ScreenResolution  1272 non-null   object
#  4   Cpu               1272 non-null   object
#  5   Ram               1272 non-null   object
#  6   Memory            1272 non-null   object
#  7   Gpu               1272 non-null   object
#  8   OpSys             1272 non-null   object
#  9   Weight            1272 non-null   object
#  10  Price             1272 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 119.2+ KB

# %%
index2 = df[df.Inches.astype(float) >= 25.0].index

df.drop(index2,inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1265 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1265 non-null   object
#  1   TypeName          1265 non-null   object
#  2   Inches            1265 non-null   object
#  3   ScreenResolution  1265 non-null   object
#  4   Cpu               1265 non-null   object
#  5   Ram               1265 non-null   object
#  6   Memory            1265 non-null   object
#  7   Gpu               1265 non-null   object
#  8   OpSys             1265 non-null   object
#  9   Weight            1265 non-null   object
#  10  Price             1265 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 118.6+ KB

# %%
df['ScreenResolution'].unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', '1600x900',
#        'IPS Panel 4K Ultra HD 3840x2160', '4K Ultra HD 3840x2160',
#        'Touchscreen 1366x768', 'Touchscreen 2560x1440',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
#        'IPS Panel Quad HD+ 3200x1800',
#        'IPS Panel Quad HD+ / Touchscreen 3200x1800',
#        'IPS Panel Touchscreen 1366x768', '1920x1080',
#        'IPS Panel Full HD 1920x1200',
#        'IPS Panel Touchscreen / 4K Ultra HD 3840x2160',
#        'IPS Panel Touchscreen 2560x1440',
#        'Touchscreen / Full HD 1920x1080', 'Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200',
#        'Touchscreen / 4K Ultra HD 3840x2160',
#        'IPS Panel Touchscreen 2400x1600'], dtype=object)

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Core i5 7300HQ 2.5GHz',
#        'AMD E-Series E2-9000e 1.5GHz', 'Intel Core i5 1.6GHz',
#        'Intel Core i7 8650U 1.9GHz', 'Intel Atom x5-Z8300 1.44GHz',
#        'AMD E-Series E2-6110 1.5GHz', 'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
#        'Intel Celeron Dual Core N3060 1.6GHz', 'Intel Core i5 1.3GHz',
#        'AMD FX 9830P 3GHz', 'Intel Core i7 7560U 2.4GHz',
#        'AMD E-Series 6110 1.5GHz', 'Intel Core i5 6200U 2.3GHz',
#        'Intel Core M 6Y75 1.2GHz', 'Intel Core i5 7500U 2.7GHz',
#        'Intel Core i3 6006U 2.2GHz', 'AMD A6-Series 9220 2.9GHz',
#        'Intel Core i7 6920HQ 2.9GHz', 'Intel Core i5 7Y54 1.2GHz',
#        'Intel Core i7 7820HK 2.9GHz', 'Intel Xeon E3-1505M V6 3GHz',
#        'Intel Core i7 6500U 2.5GHz', 'AMD E-Series 9000e 1.5GHz',
#        'AMD A10-Series A10-9620P 2.5GHz', 'AMD A6-Series A6-9220 2.5GHz',
#        'Intel Core i5 2.9GHz', 'Intel Core i7 6600U 2.6GHz',
#        'Intel Core i3 6006U 2.0GHz',
#        'Intel Celeron Dual Core 3205U 1.5GHz',
#        'Intel Core i7 7820HQ 2.9GHz', 'AMD A10-Series 9600P 2.4GHz',
#        'Intel Core i7 7600U 2.8GHz', 'AMD A8-Series 7410 2.2GHz',
#        'Intel Celeron Dual Core 3855U 1.6GHz',
#        'Intel Pentium Quad Core N3710 1.6GHz',
#        'AMD A12-Series 9720P 2.7GHz', 'Intel Core i5 7300U 2.6GHz',
#        'AMD A12-Series 9720P 3.6GHz',
#        'Intel Celeron Quad Core N3450 1.1GHz',
#        'Intel Celeron Dual Core N3060 1.60GHz',
#        'Intel Core i5 6440HQ 2.6GHz', 'Intel Core i7 6820HQ 2.7GHz',
#        'AMD Ryzen 1600 3.2GHz', 'Intel Core i7 7Y75 1.3GHz',
#        'Intel Core i5 7440HQ 2.8GHz', 'Intel Core i7 7660U 2.5GHz',
#        'Intel Core i7 7700HQ 2.7GHz', 'Intel Core M m3-7Y30 2.2GHz',
#        'Intel Core i5 7Y57 1.2GHz', 'Intel Core i7 6700HQ 2.6GHz',
#        'Intel Core i3 6100U 2.3GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'AMD A10-Series 9620P 2.5GHz', 'AMD E-Series 7110 1.8GHz',
#        'Intel Celeron Dual Core N3350 2.0GHz',
#        'AMD A9-Series A9-9420 3GHz', 'Intel Core i7 6820HK 2.7GHz',
#        'Intel Xeon E3-1535M v6 3.1GHz',
#        'Intel Celeron Quad Core N3160 1.6GHz',
#        'Intel Core i5 6300U 2.4GHz', 'Intel Core i3 6100U 2.1GHz',
#        'Intel Celeron Dual Core N3050 1.6GHz',
#        'Intel Core M M3-6Y30 0.9GHz', 'AMD A9-Series 9420 2.9GHz',
#        'Intel Core i5 6300HQ 2.3GHz', 'AMD A6-Series 7310 2GHz',
#        'Intel Atom Z8350 1.92GHz', 'Intel Xeon E3-1535M v5 2.9GHz',
#        'Intel Core i5 6260U 1.8GHz',
#        'Intel Pentium Dual Core N4200 1.1GHz',
#        'Intel Celeron Quad Core N3710 1.6GHz', 'Intel Core M 1.2GHz',
#        'AMD A12-Series 9700P 2.5GHz', 'Intel Core i7 7500U 2.5GHz',
#        'Intel Pentium Dual Core 4405U 2.1GHz',
#        'AMD A4-Series 7210 2.2GHz', 'Intel Core i7 6560U 2.2GHz',
#        'Intel Core M m7-6Y75 1.2GHz', 'AMD FX 8800P 2.1GHz',
#        'Intel Core M M7-6Y75 1.2GHz', 'Intel Core i5 7200U 2.50GHz',
#        'Intel Core i5 7200U 2.70GHz', 'Intel Atom X5-Z8350 1.44GHz',
#        'Intel Core i5 7200U 2.7GHz', 'Intel Core M 1.1GHz',
#        'Intel Atom x5-Z8550 1.44GHz',
#        'Intel Pentium Dual Core 4405Y 1.5GHz',
#        'Intel Pentium Quad Core N3700 1.6GHz', 'Intel Core M 6Y54 1.1GHz',
#        'Intel Core i7 6500U 2.50GHz',
#        'Intel Celeron Dual Core N3350 2GHz',
#        'Samsung Cortex A72&A53 2.0GHz', 'AMD E-Series 9000 2.2GHz',
#        'Intel Core M 6Y30 0.9GHz', 'AMD A9-Series 9410 2.9GHz'],
#       dtype=object)

# %%
df['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '64GB', '6GB', '32GB', '24GB',
#        '1GB'], dtype=object)

# %%
index3 = df[df.Ram == '1GB'].index
index4 = df[df.Ram == '24GB'].index
index5 = df[df.Ram == '64GB'].index

df.drop(index3,inplace =True)
df.drop(index4,inplace =True)
df.drop(index5,inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1258 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1258 non-null   object
#  1   TypeName          1258 non-null   object
#  2   Inches            1258 non-null   object
#  3   ScreenResolution  1258 non-null   object
#  4   Cpu               1258 non-null   object
#  5   Ram               1258 non-null   object
#  6   Memory            1258 non-null   object
#  7   Gpu               1258 non-null   object
#  8   OpSys             1258 non-null   object
#  9   Weight            1258 non-null   object
#  10  Price             1258 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 117.9+ KB

# %%
df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '?', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
df['OpSys'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux',
#        'Windows 10 S', 'Chrome OS', 'Windows 7', 'Android'], dtype=object)

# %%
index6 = df[df.OpSys == 'No OS'].index
index7 = df[df.OpSys == 'Chrome OS'].index
index8 = df[df.OpSys == 'Android'].index

df.drop(index6,inplace =True)
df.drop(index7,inplace =True)
df.drop(index8,inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1167 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1167 non-null   object
#  1   TypeName          1167 non-null   object
#  2   Inches            1167 non-null   object
#  3   ScreenResolution  1167 non-null   object
#  4   Cpu               1167 non-null   object
#  5   Ram               1167 non-null   object
#  6   Memory            1167 non-null   object
#  7   Gpu               1167 non-null   object
#  8   OpSys             1167 non-null   object
#  9   Weight            1167 non-null   object
#  10  Price             1167 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 109.4+ KB

# %%
df['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg', '1.6kg',
#        '2.2kg', '0.92kg', '1.22kg', '2.5kg', '1.62kg', '1.91kg', '2.3kg',
#        '1.35kg', '1.88kg', '1.89kg', '1.65kg', '2.71kg', '1.2kg',
#        '1.44kg', '2.8kg', '1.86kg', '2kg', '2.65kg', '2.77kg', '3.2kg',
#        '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg', '1.4kg', '1.8kg',
#        '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg', '1.63kg', '1.96kg',
#        '1.21kg', '2.45kg', '1.25kg', '1.5kg', '2.62kg', '1.38kg',
#        '1.58kg', '1.85kg', '1.23kg', '2.16kg', '2.36kg', '7.2kg',
#        '2.05kg', '1.32kg', '1.75kg', '0.97kg', '2.56kg', '1.48kg',
#        '1.74kg', '1.1kg', '1.56kg', '2.03kg', '1.05kg', '5.4kg', '4.4kg',
#        '1.90kg', '1.29kg', '2.0kg', '2.06kg', '1.12kg', '3.49kg',
#        '3.35kg', '2.23kg', '?', '2.9kg', '4.42kg', '2.69kg', '2.37kg',
#        '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg', '1.41kg', '4.14kg',
#        '2.18kg', '2.24kg', '2.67kg', '4.1kg', '2.14kg', '1.36kg',
#        '2.25kg', '2.15kg', '1.95kg', '2.54kg', '3.42kg', '5.8kg',
#        '1.28kg', '2.33kg', '2.79kg', '8.23kg', '1.26kg', '1.84kg',
#        '0.0002kg', '2.6kg', '2.26kg', '3.25kg', '1.59kg', '1.13kg',
#        '1.42kg', '1.78kg', '1.10kg', '1.15kg', '1.27kg', '1.43kg',
#        '2.31kg', '1.16kg', '1.64kg', '2.17kg', '1.47kg', '3.78kg',
#        '1.79kg', '0.91kg', '1.99kg', '1.93kg', '1.87kg', '2.63kg',
#        '3.4kg', '3.14kg', '1.94kg', '1.24kg', '4.6kg', '1.45kg', '4.5kg',
#        '8.4kg', '2.73kg', '2.29kg', '2.59kg', '2.94kg', '11.1kg',
#        '1.14kg', '3.8kg', '6.2kg', '3.31kg', '1.09kg', '3.21kg', '1.19kg',
#        '1.98kg', '2.19kg', '4.36kg', '1.71kg', '2.32kg', '4.2kg',
#        '1.55kg', '0.81kg', '1.18kg', '2.72kg', '1.31kg', '0.920kg',
#        '3.74kg', '1.76kg', '1.54kg', '2.83kg', '2.07kg', '2.38kg',
#        '1.17kg', '3.58kg', '1.08kg', '0.98kg', '2.75kg', '1.70kg',
#        '2.99kg', '1.11kg', '2.09kg', '3.0kg', '0.99kg', '0.69kg',
#        '3.52kg', '2.591kg', '2.21kg', '3.3kg', '2.191kg', '2.34kg',
#        '4.0kg', '2.20kg'], dtype=object)

# %%
index9 = df[df.Weight == '?'].index

df.drop(index9,inplace = True)

# %%
df['Weight_in_kg'] = df['Weight'].apply(lambda x: float(x.split('kg')[0]))

df.drop(columns = 'Weight',inplace = True)
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook   15.6                            1366x768
#
#                        Cpu   Ram               Memory  \
# 0     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4     Intel Core i5 3.1GHz   8GB            256GB SSD
# 5  AMD A9-Series 9420 3GHz   4GB            500GB HDD
#
#                             Gpu       OpSys        Price  Weight_in_kg
# 0  Intel Iris Plus Graphics 640       macOS   71378.6832          1.37
# 1        Intel HD Graphics 6000       macOS   47895.5232          1.34
# 3            AMD Radeon Pro 455       macOS  135195.3360          1.83
# 4  Intel Iris Plus Graphics 650       macOS   96095.8080          1.37
# 5                 AMD Radeon R5  Windows 10   21312.0000          2.10

# %%
index10 = df[df.Weight_in_kg <= 1].index

index11 = df[df.Weight_in_kg > 3.5].index

df.drop(index10,inplace = True)

df.drop(index11,inplace = True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1099 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1099 non-null   object
#  1   TypeName          1099 non-null   object
#  2   Inches            1099 non-null   object
#  3   ScreenResolution  1099 non-null   object
#  4   Cpu               1099 non-null   object
#  5   Ram               1099 non-null   object
#  6   Memory            1099 non-null   object
#  7   Gpu               1099 non-null   object
#  8   OpSys             1099 non-null   object
#  9   Price             1099 non-null   float64
#  10  Weight_in_kg      1099 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 103.0+ KB

# %%
df['Price'].describe()
# Out:
# count      1099.000000
# mean      59022.182915
# std       34627.058188
# min       10442.880000
# 25%       34045.653600
# 50%       52161.120000
# 75%       77466.456000
# max      324954.720000
# Name: Price, dtype: float64

# %%
index11 = df[df.Price > 250000].index 

index12 = df[df.Price < 20000].index

df.drop(index11,inplace = True)
df.drop(index12,inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 0 to 1301
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1016 non-null   object
#  1   TypeName          1016 non-null   object
#  2   Inches            1016 non-null   object
#  3   ScreenResolution  1016 non-null   object
#  4   Cpu               1016 non-null   object
#  5   Ram               1016 non-null   object
#  6   Memory            1016 non-null   object
#  7   Gpu               1016 non-null   object
#  8   OpSys             1016 non-null   object
#  9   Price             1016 non-null   float64
#  10  Weight_in_kg      1016 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 95.2+ KB

# %%
dummies1 = pd.get_dummies(df['Company'])

dummies2 = pd.get_dummies(df['TypeName'])

dummies3 = pd.get_dummies(df['ScreenResolution'])

dummies4 = pd.get_dummies(df['Ram'])

dummies5 = pd.get_dummies(df['Memory'])

dummies6 = pd.get_dummies(df['Gpu'])

dummies7 = pd.get_dummies(df['OpSys'])

dummies8 = pd.get_dummies(df['Cpu'])

df2 = pd.concat([df,dummies1,dummies2,dummies3,dummies4,dummies5,dummies6,dummies7,dummies8],axis = 'columns')
df2.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook   15.6                            1366x768
#
#                        Cpu   Ram               Memory  \
# 0     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4     Intel Core i5 3.1GHz   8GB            256GB SSD
# 5  AMD A9-Series 9420 3GHz   4GB            500GB HDD
#
#                             Gpu       OpSys        Price  ...  \
# 0  Intel Iris Plus Graphics 640       macOS   71378.6832  ...
# 1        Intel HD Graphics 6000       macOS   47895.5232  ...
# 3            AMD Radeon Pro 455       macOS  135195.3360  ...
# 4  Intel Iris Plus Graphics 650       macOS   96095.8080  ...
# 5                 AMD Radeon R5  Windows 10   21312.0000  ...
#
#    Intel Core i7 7Y75 1.3GHz  Intel Core i7 8550U 1.8GHz  \
# 0                          0                           0
# 1                          0                           0
# 3                          0                           0
# 4                          0                           0
# 5                          0                           0
#
#    Intel Core i7 8650U 1.9GHz  Intel Pentium Dual Core 4405U 2.1GHz  \
# 0                           0                                     0
# 1                           0                                     0
# 3                           0                                     0
# 4                           0                                     0
# 5                           0                                     0
#
#    Intel Pentium Dual Core N4200 1.1GHz  Intel Pentium Quad Core N3700 1.6GHz  \
# 0                                     0                                     0
# 1                                     0                                     0
# 3                                     0                                     0
# 4                                     0                                     0
# 5                                     0                                     0
#
#    Intel Pentium Quad Core N3710 1.6GHz  Intel Pentium Quad Core N4200 1.1GHz  \
# 0                                     0                                     0
# 1                                     0                                     0
# 3                                     0                                     0
# 4                                     0                                     0
# 5                                     0                                     0
#
#    Intel Xeon E3-1505M V6 3GHz  Intel Xeon E3-1535M v5 2.9GHz
# 0                            0                              0
# 1                            0                              0
# 3                            0                              0
# 4                            0                              0
# 5                            0                              0
#
# [5 rows x 294 columns]

# %%
df2.drop(columns = ['Company','TypeName','ScreenResolution','Cpu','Ram','Memory','Gpu','OpSys'],inplace = True)
df2.head()
# Out:
#   Inches        Price  Weight_in_kg  Acer  Apple  Asus  Chuwi  Dell  Fujitsu  \
# 0   13.3   71378.6832          1.37     0      1     0      0     0        0
# 1   13.3   47895.5232          1.34     0      1     0      0     0        0
# 3   15.4  135195.3360          1.83     0      1     0      0     0        0
# 4   13.3   96095.8080          1.37     0      1     0      0     0        0
# 5   15.6   21312.0000          2.10     1      0     0      0     0        0
#
#    HP  ...  Intel Core i7 7Y75 1.3GHz  Intel Core i7 8550U 1.8GHz  \
# 0   0  ...                          0                           0
# 1   0  ...                          0                           0
# 3   0  ...                          0                           0
# 4   0  ...                          0                           0
# 5   0  ...                          0                           0
#
#    Intel Core i7 8650U 1.9GHz  Intel Pentium Dual Core 4405U 2.1GHz  \
# 0                           0                                     0
# 1                           0                                     0
# 3                           0                                     0
# 4                           0                                     0
# 5                           0                                     0
#
#    Intel Pentium Dual Core N4200 1.1GHz  Intel Pentium Quad Core N3700 1.6GHz  \
# 0                                     0                                     0
# 1                                     0                                     0
# 3                                     0                                     0
# 4                                     0                                     0
# 5                                     0                                     0
#
#    Intel Pentium Quad Core N3710 1.6GHz  Intel Pentium Quad Core N4200 1.1GHz  \
# 0                                     0                                     0
# 1                                     0                                     0
# 3                                     0                                     0
# 4                                     0                                     0
# 5                                     0                                     0
#
#    Intel Xeon E3-1505M V6 3GHz  Intel Xeon E3-1535M v5 2.9GHz
# 0                            0                              0
# 1                            0                              0
# 3                            0                              0
# 4                            0                              0
# 5                            0                              0
#
# [5 rows x 286 columns]

# %%
from sklearn.model_selection import train_test_split

x = df2.drop(columns = 'Price')
y = df2['Price']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 10)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred = lr.predict(x_test)
#r2_score(y_test,y_pred)
y_pred
# Out:
# array([ 2.01921875e+04,  4.29760411e+13,  6.47229375e+04,  4.84726250e+04,
#         6.55895625e+04,  5.90015625e+04,  7.98009375e+04,  9.65464375e+04,
#         1.07348062e+05,  6.59086250e+04,  6.15600625e+04,  2.52013750e+04,
#         4.99601875e+04,  3.74176875e+04,  8.04941250e+04,  4.51379375e+04,
#         3.36033750e+04,  9.06834375e+04, -9.23795112e+11,  4.29757343e+13,
#         4.29757342e+13,  5.85381250e+04,  1.15377312e+05,  5.76164375e+04,
#         5.67803750e+04,  7.60630625e+04, -9.23730807e+11,  3.63273125e+04,
#         7.70095000e+04, -2.85024931e+13, -7.00899832e+13,  2.42786875e+04,
#         4.44676875e+04,  5.91191250e+04,  6.66867500e+04,  8.60125000e+04,
#         3.76744375e+04,  8.40028750e+04,  4.29757340e+13,  7.63180000e+04,
#         3.62238125e+04,  4.75547500e+04, -4.97091769e+13,  4.85180625e+04,
#         5.92415625e+04,  4.29757503e+13,  3.16479375e+04,  6.61993750e+04,
#         5.93219375e+04,  3.03425000e+04,  5.18272500e+04,  6.38033125e+04,
#         4.43264375e+04,  5.49825000e+04,  2.85366250e+04,  4.29757342e+13,
#         3.49482500e+04,  4.33218125e+04,  1.90790625e+04,  5.08261875e+04,
#         2.79840000e+04,  6.75581875e+04,  4.38995211e+13,  4.84686875e+04,
#         4.80026875e+04,  8.60463750e+04,  1.02367938e+05,  4.01988750e+04,
#         4.20146875e+04,  1.16591938e+05,  5.04850625e+04,  8.06547500e+04,
#         7.63487500e+04,  3.39486250e+04,  4.77880000e+04,  4.67541875e+04,
#         9.45627500e+04,  5.77859375e+04,  6.26973125e+04,  3.47794375e+04,
#         5.03550625e+04,  5.49114375e+04,  6.66867500e+04,  5.57711875e+04,
#         9.31426875e+04,  5.07420625e+04,  7.55181875e+04,  2.39040000e+04,
#         1.27636438e+05,  3.25373750e+04,  5.49959375e+04,  6.96802500e+04,
#         6.01171250e+04, -9.28745039e+13,  4.89636875e+04,  4.06210625e+04,
#         6.65161875e+04,  5.59890625e+04,  4.06577500e+04,  3.60408125e+04,
#         8.83940000e+04,  1.48553250e+05,  1.86740000e+04,  8.47877500e+04,
#         5.14540000e+04,  3.44381875e+04,  5.42659375e+04,  7.18828125e+04,
#         6.61430625e+04,  9.66214375e+04,  2.48866250e+04,  4.38995212e+13,
#         9.39859375e+04,  4.89538750e+04, -2.61904621e+13,  8.35388125e+04,
#         1.23523312e+05,  3.18306915e+14,  3.30977500e+04,  1.03306812e+05,
#         4.17020625e+04,  4.94418125e+04,  1.75062674e+14,  4.98099375e+04,
#         4.58435625e+04,  2.70712855e+13,  6.22305000e+04,  5.78789375e+04,
#         3.39644375e+04,  5.53104375e+04,  3.95881875e+04,  5.90165625e+04,
#         7.63180000e+04,  2.13251250e+04,  3.73824375e+04,  4.08870625e+04,
#         6.18549375e+04,  6.26218125e+04,  8.17483750e+04,  7.61591875e+04,
#         7.14678125e+04,  5.15168750e+04,  8.74659375e+04,  5.21354375e+04,
#         5.26584375e+04, -1.21733001e+13,  5.54644375e+04,  8.33378125e+04,
#         5.90015625e+04,  4.78630625e+04,  1.93833125e+04,  3.86528750e+04,
#         2.08468750e+04,  1.09681562e+05,  3.80918125e+04,  2.90513125e+04,
#         4.38995212e+13,  3.60408125e+04,  3.04059375e+04,  1.08277500e+05,
#         6.78979375e+04,  4.49536875e+04,  8.56106250e+04,  4.34019375e+04,
#         6.90490625e+04,  4.52223750e+04,  4.48275625e+04,  6.02446250e+04,
#         6.33888750e+04,  9.80240625e+04,  6.05954375e+04,  2.70311250e+04,
#         8.28381875e+04,  4.20779375e+04,  3.08492500e+04,  9.19330000e+04,
#         6.27779375e+04,  9.79243125e+04,  1.75062674e+14,  5.14319375e+04,
#         2.46958125e+04,  9.76640625e+04,  1.20523812e+05,  6.77395625e+04,
#         6.25096875e+04,  4.95731875e+04,  4.38995211e+13,  5.97160625e+04,
#        -9.23786844e+11,  7.34403125e+04,  6.19015625e+04,  7.22099375e+04,
#         8.47133125e+04,  4.64924460e+13,  3.47352500e+04,  6.83040000e+04,
#         1.12005188e+05,  5.39475000e+04,  9.84121875e+04,  6.53798750e+04,
#         5.72028750e+04,  1.01154625e+05,  6.24193125e+04,  2.78836250e+04])

# %%
y_test
# Out:
# 1278    20193.1200
# 387     72940.3200
# 344     84129.1200
# 813     51202.0800
# 1219    61218.7200
#            ...
# 1058    69210.7200
# 1101    62176.1616
# 488     95797.4400
# 310     53226.7200
# 541     39207.1536
# Name: Price, Length: 204, dtype: float64
